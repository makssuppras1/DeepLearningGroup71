# %%
import wandb

# placeholder for hidden layers lists: [[128], [128, 64], [128, 64, 32], [512, 256]]
sweep_config = {
    'program': 'train3.py',
    'method': 'grid',
    'project': 'neural-network-numpy',
    'name': 'sweep_grid',
    'early_terminate': {
        'type': 'hyperband',
        'min_iter': 3,
        }
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric


parameters_dict = {
    'optimizer': {
        'values': ['adam']
        },
    'num_hidden_layers': {
        'values': [2, 3, 4, 5, 6, 7, 8, 9, 10]
        },
    'num_neurons': {
        'values': [2, 4, 8, 16, 32, 64, 128, 256]
        },
    'l2_lambda': {
        # a log-uniform distribution between 1e-6 and 1e-2
        'values': [0.001, 0.0001, 0.00001]
        },
    'learning_rate': {
        # a flat distribution between 0 and 0.1
        'values': [0.001, 0.0001, 0.00001]
      },
    'batch_size': {
        'values': [32, 64, 128]
      }
    }

sweep_config['parameters'] = parameters_dict



sweep_id = wandb.sweep(sweep_config)
wandb.agent(sweep_id)
# Out:
# Create sweep with ID: pdj2yk83
# Sweep URL: https://wandb.ai/makssuppras1-danmarks-tekniske-universitet-dtu/neural-network-numpy/sweeps/pdj2yk83
# wandb: Agent Starting Run: pq7loodz with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m1drmrjb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m1drmrjb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ouiqt1kv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ouiqt1kv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2szvnhhr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2szvnhhr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: kunxb8yf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: kunxb8yf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9qatgxzm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9qatgxzm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: zllrazjr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: zllrazjr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: f03o4baa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: f03o4baa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yttykrqy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yttykrqy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: loukm5d4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: loukm5d4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7tgcgeo6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7tgcgeo6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tkuqmfun with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tkuqmfun with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6ogsazih with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6ogsazih with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1tf9ione with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1tf9ione with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ibgtageh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ibgtageh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r14fvstt with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r14fvstt with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6elr53bh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6elr53bh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: sbkp5d17 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: sbkp5d17 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2jhnztdy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2jhnztdy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m0ff5l4p with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m0ff5l4p with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: giis7ftc with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: giis7ftc with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: k9685lre with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: k9685lre with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: e3a4txqg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: e3a4txqg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 32rx9sfk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 32rx9sfk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j48dfrx9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j48dfrx9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cgvrcczm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cgvrcczm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cidhtme6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cidhtme6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 27f4twfq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 27f4twfq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wvdhc8r9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wvdhc8r9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6z81rwms with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 6z81rwms with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6x5oaza with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6x5oaza with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ky9fjs4a with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ky9fjs4a with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dwtbeyt8 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dwtbeyt8 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: y7n2i9lm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: y7n2i9lm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7b1gzole with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7b1gzole with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1zq71pf3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1zq71pf3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: uu6fl8mj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: uu6fl8mj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: umi59ako with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: umi59ako with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 98g7jfoq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 98g7jfoq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9x21hee7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9x21hee7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 71ipnvah with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 71ipnvah with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: drmtphmv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: drmtphmv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m55jim97 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: m55jim97 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: hawe27t1 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: hawe27t1 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q6flhxvp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q6flhxvp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r1tujg0l with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r1tujg0l with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4qq29yw7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4qq29yw7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wuc5sfck with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wuc5sfck with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: f9fki7kj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: f9fki7kj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gp85rrw2 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gp85rrw2 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t1pjnshm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t1pjnshm with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t7izmkxa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t7izmkxa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 5zk1yb8r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 5zk1yb8r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9bx5ilik with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9bx5ilik with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4wklznc5 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4wklznc5 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 07uli6nj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 07uli6nj with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ajolbebo with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ajolbebo with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: y85jqg3n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: y85jqg3n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: b76nkeao with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: b76nkeao with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6hfoxb1 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6hfoxb1 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: l8er017p with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: l8er017p with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 3yfy7vaa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 3yfy7vaa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 18kz9hub with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 18kz9hub with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1int89h6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1int89h6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6nsskcs with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: d6nsskcs with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 035lqiag with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 035lqiag with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v2pdw332 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v2pdw332 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: emfnft2r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: emfnft2r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: pxellfju with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: pxellfju with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lhhbnvro with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lhhbnvro with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: o79nksn0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: o79nksn0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gh2lbadf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gh2lbadf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j1pc42td with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j1pc42td with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: plb1nqs4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: plb1nqs4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r5cgz7n3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: r5cgz7n3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: x3rtg3sw with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: x3rtg3sw with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: fwehd3bv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: fwehd3bv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xnu8i52f with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xnu8i52f with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 18biqlnq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 18biqlnq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmjbznkv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmjbznkv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dafx9zmb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dafx9zmb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: vlt9pp7w with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: vlt9pp7w with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 8csr05ny with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 8csr05ny with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: p90xx8je with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: p90xx8je with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: umva9oct with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: umva9oct with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: k5kadwrh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: k5kadwrh with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: h9grpjv3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: h9grpjv3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9k8lx00m with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9k8lx00m with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wqeubjhy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wqeubjhy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4watmbej with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 4watmbej with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 5045k1qv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 5045k1qv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t6anuhjp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: t6anuhjp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9uvi9ezf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9uvi9ezf with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bay4ftfz with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bay4ftfz with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mu1rfxfa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mu1rfxfa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: qsyfwspv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: qsyfwspv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7dz89dp3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 7dz89dp3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmu198qr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmu198qr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cujxs4vl with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: cujxs4vl with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j7zhr96e with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: j7zhr96e with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: zxeo9dy0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: zxeo9dy0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 0f3lj1ll with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 0f3lj1ll with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1ubb2amg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 1ubb2amg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q3xy5152 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q3xy5152 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 5
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: z9bcxp7n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: z9bcxp7n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9yne77pa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 9yne77pa with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: azk7g6en with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: azk7g6en with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 862ipl9k with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 862ipl9k with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: c1wzxnuy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: c1wzxnuy with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tu3ia75f with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tu3ia75f with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gs756itr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gs756itr with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mqj164y3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mqj164y3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 6
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yfv45kth with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yfv45kth with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gmytrsbp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gmytrsbp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: i8m2bs3u with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: i8m2bs3u with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: c84cs86r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: c84cs86r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bdjazut6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bdjazut6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v9d7f29z with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v9d7f29z with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 7
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: g5t7rjdd with config:
# wandb: 	batch_size: 32
# ...
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mjiff7k2 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q04w60bb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q04w60bb with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: fbvidkz7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: fbvidkz7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: skggby3k with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: skggby3k with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 8ytjbz27 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 8ytjbz27 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jk39ud2s with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jk39ud2s with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xduoisma with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xduoisma with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 8
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yl0w75nk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: yl0w75nk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mfjt88za with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: mfjt88za with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 851mwmnk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 851mwmnk with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: kltvnq4u with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: kltvnq4u with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: sg4kqo1r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: sg4kqo1r with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: o24cwycs with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: o24cwycs with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2fa8w1a9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 2fa8w1a9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tdh0m9j0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: tdh0m9j0 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 9
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bq9ggay6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: bq9ggay6 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jphwvuz8 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jphwvuz8 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: s9jels6s with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: s9jels6s with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: z6jauf9t with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: z6jauf9t with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 62ba2dx3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 62ba2dx3 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: n1ope6ix with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: n1ope6ix with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gwor7opu with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: gwor7opu with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lljrhiee with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lljrhiee with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 10
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q8di6bnx with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: q8di6bnx with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 98hrkafg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 98hrkafg with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: w7s8mlav with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: w7s8mlav with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: co5jfvcq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: co5jfvcq with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 47u8mirv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: 47u8mirv with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v9nbztk9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: v9nbztk9 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: spe16jh4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: spe16jh4 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ihhz2kby with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: ihhz2kby with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 2
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: pu7lzplp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: pu7lzplp with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 2
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lhfv01tt with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: lhfv01tt with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 4
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dms7sm83 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: dms7sm83 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 8
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wpa5et6n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: wpa5et6n with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 16
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: uq9vtx0e with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: uq9vtx0e with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 32
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jyvwjuf7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: jyvwjuf7 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 64
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmpe94pe with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: xmpe94pe with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 128
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: toj4fvn5 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Agent Starting Run: toj4fvn5 with config:
# wandb: 	batch_size: 32
# wandb: 	l2_lambda: 0.001
# wandb: 	learning_rate: 1e-05
# wandb: 	num_hidden_layers: 3
# wandb: 	num_neurons: 256
# wandb: 	optimizer: adam
# wandb: Ctrl-c pressed. Waiting for runs to end. Press ctrl-c again to terminate them.
# wandb: Ctrl-c pressed. Waiting for runs to end. Press ctrl-c again to terminate them.

# %% [markdown]
# >Genstart sweep

# %%
import wandb
wandb.agent(sweep_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import wandb
# ----> 2 wandb.agent(sweep_id)
#
# NameError: name 'sweep_id' is not defined
